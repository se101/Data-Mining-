# %% [markdown]
# # Data Mining Project
# ____________________________________________________________

# %% [markdown]
# ## Dataset: IABR (Indian Birth Recode)

# %%
"""
DFS data mining project

Dataset: IABR (Indian Birth Recode)

Item Name              Item Label                                     Start  Len Type Type  Occ  Dec Char Fill
_______________________________________________________________________________________________________________
V010                   Respondent's year of birth                        60    4    N    I    1    0   No   No
V012                   Current age - respondent                          68    2    N    I    1    0   No   No
V023                   Sample domain                                     93    2    N    I    1    0   No   No
V024                   State                                             95    2    N    I    1    0   No   No
V025                   Type of place of residence                        97    1    N    I    1    0   No   No
V113                   Source of drinking water                         140    2    N    I    1    0   No   No
V116                   Type of toilet facility                          145    2    N    I    1    0   No   No
V155                   Literacy                                         210    1    N    I    1    0   No   No
V161                   Type of cooking fuel                             216    2    N    I    1    0   No   No
V190                   Wealth index                                     224    1    N    I    1    0   No   No
V201                   Total children ever born                         234    2    N    I    1    0   No   No
V453                   Hemoglobin test result (g/dl - 1 decimal)        556    3    N    I    1    0   No   No
V457                   Anemia level (from V456) adjusted for pregnancy  564    1    N    I    1    0   No   No
H2                     Received BCG                                    1008    1    N    I    1    0   No   No
                               0  No
                               1  Vaccination date on card
                               2  Reported by mother
                               3  Vaccination marked on card
                               8  Don't know
                           (m) 9  Missing
                          (na)    Not applicable
H3                     Received DPT 1                                  1017    1    N    I    1    0   No   No
H4                     Received POLIO 1                                1026    1    N    I    1    0   No   No
H5                     Received DPT 2                                  1035    1    N    I    1    0   No   No
H6                     Received POLIO 2                                1044    1    N    I    1    0   No   No
H7                     Received DPT 3                                  1053    1    N    I    1    0   No   No
H8                     Received POLIO 3                                1062    1    N    I    1    0   No   No
H9                     Received MEASLES                                1071    1    N    I    1    0   No   No
H0                     Received POLIO 0                                1080    1    N    I    1    0   No   No

V106                   Highest educational level                        137    1    N    I    1    0   No   No
V107                   Highest year of education                        138    2    N    I    1    0   No   No
V133                   Education in single years                        164    2    N    I    1    0   No   No
SV122                  Educational level during 2005-06 school year    1680    1    N    I    1    0   No   No
SV123                  Grade of education during 2005-06 school year   1681    2    N    I    1    0   No   No
SV124                  Education in single years for 2005-06 school ye 1683    2    N    I    1    0   No   No
SV125                  Attended school during 2004-05 school year      1685    1    N    I    1    0   No   No
SV126                  Educational level during 2004-05 school year    1686    1    N    I    1    0   No   No
SV127                  Grade of education during 2004-05 school year   1687    2    N    I    1    0   No   No
SV128                  Education in single years for 2004-05 school ye 1689    2    N    I    1    0   No   No

LITERACY and living condition, diseases, vaccinations, wealth index
"""

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading the Data

# %%
df = pd.read_csv(r"IABR/IABR2005-06.csv")
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_12048\3328889587.py:1: DtypeWarning: Columns (88,116,365,366,368,369,370,371,372,373,374,375,376,377,378,379,380,381,401,405,406,407,408,409,410,413,414,416,426,429,451,452,453,454,457,462,844,847,848,849,863,877,878,923,928,929,930,931,932,934,1021,1022,1023,1024,1025,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1051,1052,1053,1054,1055,1056,1057,1076,1090,1106,1107) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"IABR/IABR2005-06.csv")

# %%
df
# Out:
#                  CASEID  BIDX V000   V001  V002  V003 V004     V005  V006  \
# 0          28  1   1  2     1  IA5  28001     1     2       2474583     1
# 1          28  1   1  2     2  IA5  28001     1     2       2474583     1
# 2          28  1   1  2     3  IA5  28001     1     2       2474583     1
# 3          28  1   1  2     4  IA5  28001     1     2       2474583     1
# 4          28  1   1  4     1  IA5  28001     1     4       2474583     1
# ...                 ...   ...  ...    ...   ...   ...  ...      ...   ...
# 256777     19205  27  7     1  IA5  19205    27     7       2282738     1
# 256778     19205  28  2     1  IA5  19205    28     2       2282738     1
# 256779     19205  28  2     2  IA5  19205    28     2       2282738     1
# 256780     19205  29  2     1  IA5  19205    29     2       2282738     1
# 256781     19205  29  2     2  IA5  19205    29     2       2282738     1
#
#         V007  ...  S585  S586  S587  S588A  S588B  S588C  S589  S590A  S590B  \
# 0       2006  ...
# 1       2006  ...
# 2       2006  ...
# 3       2006  ...
# 4       2006  ...     0           0                          0
# ...      ...  ...   ...   ...   ...    ...    ...    ...   ...    ...    ...
# 256777  2006  ...     1     1     1      1      1      1     1      1      1
# 256778  2006  ...
# 256779  2006  ...
# 256780  2006  ...
# 256781  2006  ...
#
#         S590C
# 0
# 1
# 2
# 3
# 4
# ...       ...
# 256777      1
# 256778
# 256779
# 256780
# 256781
#
# [256782 rows x 1175 columns]

# %%
fields = ['V024', 'V106']

df15 = pd.read_csv(r"IABR/IABR2015-16.csv", skipinitialspace=True, usecols=fields)

# %%
df15
# Out:
#          V024  V106
# 0           1     0
# 1           1     0
# 2           1     0
# 3           1     1
# 4           1     1
# ...       ...   ...
# 1315612    36     2
# 1315613    36     0
# 1315614    36     0
# 1315615    36     0
# 1315616    36     0
#
# [1315617 rows x 2 columns]

# %%
fields = ['V024', 'V106']

df19 = pd.read_csv(r"IABR/IABR2019-21.csv", skipinitialspace=True, usecols=fields)

# %%
df19
# Out:
#          V024  V106
# 0           1     1
# 1           1     1
# 2           1     0
# 3           1     0
# 4           1     0
# ...       ...   ...
# 1274245    37     2
# 1274246    37     2
# 1274247    37     0
# 1274248    37     0
# 1274249    37     3
#
# [1274250 rows x 2 columns]

# %% [markdown]
# # Data Preprocessing
# ___________________________________________________________

# %% [markdown]
# #### I. Data Cleaning :
# &emsp;1. Missing Data \
# &emsp;2. Noisy Data
#
# #### II. Data Transformation :
# &emsp;1. Normalization \
# &emsp;2. Attribute Selection \
# &emsp;3. Discretization
#
# #### III. Data Reduction :
# &emsp;1. Aggregation \
# &emsp;2. Attribute Subset Selection \
# &emsp;3. Numerosity Reduction \
# &emsp;4. Dimensionality Reduction
# _________________________________________________________________________________

# %% [markdown]
# ## I. Data Cleaning

# %%
df_sample = df[['V024','V155','V106','V107','V133','H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9']]

df_sample
# Out:
#         V024  V155  V106 V107  V133 H2 H3 H4 H5 H6 H7 H8 H9
# 0         28     4     0          0
# 1         28     4     0          0
# 2         28     4     0          0
# 3         28     4     0          0
# 4         28     2     1    2     2  2  2  2  2  2  2  0  0
# ...      ...   ...   ...  ...   ... .. .. .. .. .. .. .. ..
# 256777    19     2     2    4     9  1  1  1  1  1  1  1  1
# 256778    19     2     1    4     4
# 256779    19     2     1    4     4
# 256780    19     2     1    5     5
# 256781    19     2     1    5     5
#
# [256782 rows x 13 columns]

# %%
print(df['V106'].unique())
print(df['V107'].unique())
print(df['V133'].unique())
# Out:
# [0 1 2 3 9]
# [' ' '2' '1' '5' '4' '7' '3' '6' '8' '0' '10' '9' '11']
# [ 0  2  7  6 10  4  5 12 15  9 17  8 11  3 18 16 13  1 14 20 22 99 19 21
#  23]

# %%
for i in df['V106'].unique():
    print(i, sum(df['V106']==i))
# Out:
# 0 131634
# 1 40801
# 2 72025
# 3 12302
# 9 20

# %%
for i in df['V107'].unique():
    print(i, sum(df['V107']==i))
# Out:
#   131654
# 2 17735
# 1 9933
# 5 35808
# 4 22797
# 7 7903
# 3 27368
# 6 3070
# 8 73
# 0 426
# 10 5
# 9 8
# 11 2

# %%
for i in df['V133'].unique():
    print(i, sum(df['V133']==i))
# Out:
# 0 132060
# 2 5074
# 7 11673
# 6 7362
# 10 15855
# 4 9323
# 5 17543
# 12 7775
# 15 6988
# 9 12930
# 17 2410
# 8 13766
# 11 2664
# 3 6614
# 18 406
# 16 544
# 13 750
# 1 1821
# 14 988
# 20 73
# 22 5
# 99 20
# 19 128
# 21 8
# 23 2

# %%
df['SV129'].unique()
# Out:
# array([' ', '5', '0', '9', '2', '4', '1'], dtype=object)

# %%
for i in df['SV129'].unique():
    print(i, sum(df['SV129']==i))
# Out:
#   237923
# 5 11703
# 0 7009
# 9 108
# 2 18
# 4 19
# 1 2

# %% [markdown]
# ### 1. Finding and Removing Missing Values

# %%
df_sample.isnull()
# Out:
#          V155   V023     H2     H3     H4     H5     H6     H7     H8     H9
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 256777  False  False  False  False  False  False  False  False  False  False
# 256778  False  False  False  False  False  False  False  False  False  False
# 256779  False  False  False  False  False  False  False  False  False  False
# 256780  False  False  False  False  False  False  False  False  False  False
# 256781  False  False  False  False  False  False  False  False  False  False
#
# [256782 rows x 10 columns]

# %%
df_sample.isna()
# Out:
#          V155   V023     H2     H3     H4     H5     H6     H7     H8     H9
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 256777  False  False  False  False  False  False  False  False  False  False
# 256778  False  False  False  False  False  False  False  False  False  False
# 256779  False  False  False  False  False  False  False  False  False  False
# 256780  False  False  False  False  False  False  False  False  False  False
# 256781  False  False  False  False  False  False  False  False  False  False
#
# [256782 rows x 10 columns]

# %%
df_test = df_sample.dropna()

# %%
df_test
# Out:
#         V155  V023 H2 H3 H4 H5 H6 H7 H8 H9
# 0          4    28
# 1          4    28
# 2          4    28
# 3          4    28
# 4          2    28  2  2  2  2  2  2  0  0
# ...      ...   ... .. .. .. .. .. .. .. ..
# 256777     2    19  1  1  1  1  1  1  1  1
# 256778     2    19
# 256779     2    19
# 256780     2    19
# 256781     2    19
#
# [256782 rows x 10 columns]

# %% [markdown]
# ### 2. Replacing Missing Values

# %%
df_test1 = df_sample.fillna(" ")

# %% [markdown]
# ### 3. Removing Repeated Values

# %%
df_test2 = df_sample.drop_duplicates()

# %%
df_test2
# Out:
#         V155  V023 H2 H3 H4 H5 H6 H7 H8 H9
# 0          4    28
# 4          2    28  2  2  2  2  2  2  0  0
# 5          2    28
# 6          0    28
# 9          0    28  2  2  2  2  2  0  2  0
# ...      ...   ... .. .. .. .. .. .. .. ..
# 256400     0    19  2  8  2  8  0  8  0  8
# 256414     1    19  2  2  2  2  0  0  0  8
# 256517     2    19  3  3  1  3  0  3  0  0
# 256532     2    19  3  1  1  1  0  0  0  0
# 256540     2    19  1  1  1  0  0  1  0  1
#
# [5665 rows x 10 columns]

# %% [markdown]
# ### 4. Removing Irrelevant Data

# %% [markdown]
# only using certain columns of the data, other columns are irrelevant for our analysis

# %%
df_sample = df[['V155','V024', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9']]

# %% [markdown]
# ### 5. Renaming Columns

# %% [markdown]
# renaming columns and values as per dicts given in the .map files, will be useful in interpreting the visualizations

# %%
dict = {1:'Jammu and Kashmir',
                               2:   'Himachal Pradesh',
                               3:   'Punjab',
                               5:   'Uttaranchal',
                               6:   'Haryana',
                               7:   'Delhi',
                               8:   'Rajasthan',
                               9:   'Uttar Pradesh',
                               10:  'Bihar',
                               11:  'Sikkim',
                               12:  'Arunachal Pradesh',
                               13:  'Nagaland',
                               14:  'Manipur',
                               15:  'Mizoram',
                               16:  'Tripura',
                               17:  'Meghalaya',
                               18:  'Assam',
                               19:  'West Bengal',
                               20:  'Jharkhand',
                               21:  'Orissa',
                               22:  'Chhattisgarh',
                               23:  'Madhya Pradesh',
                               24:  'Gujarat',
                               27:  'Maharashtra',
                               28:  'Andhra Pradesh',
                               29:  'Karnataka',
                               30:  'Goa',
                               32:  'Kerala',
                               33:  'Tamil Nadu', }
 
df_sample = df_sample.replace({"V024": dict})

# %%
dict = {1:   'Andaman and Nicobar Islands',
                               2:   'Andhra Pradesh',
                               3:   'Arunachal Pradesh',
                               4:   'Assam',
                               5:   'Bihar',
                               6:   'Chandigarh',
                               7:   'Chhattisgarh',
                               8:   'Dadra and Nagar Haveli',
                               9:   'Daman and Diu',
                               10:  'Goa',
                               11:  'Gujarat',
                               12:  'Haryana',
                               13:  'Himachal Pradesh',
                               14:  'Jammu and Kashmir',
                               15:  'Jharkhand',
                               16:  'Karnataka',
                               17:  'Kerala',
                               18:  'Lakshadweep',
                               19:  'Madhya Pradesh',
                               20:  'Maharashtra',
                               21:  'Manipur',
                               22:  'Meghalaya',
                               23:  'Mizoram',
                               24:  'Nagaland',
                               25:  'Delhi',
                               26:  'Odisha',
                               27:  'Puducherry',
                               28:  'Punjab',
                               29:  'Rajasthan',
                               30:  'Sikkim',
                               31:  'Tamil Nadu',
                               32:  'Tripura',
                               33:  'Uttar Pradesh',
                               34:  'Uttarakhand',
                               35:  'West Bengal',
                               36:  'Telangana',}
df15 = df15.replace({"V024": dict})

# %%
dict = {1:   'Jammu & Kashmir',
                               2:   'Himachal Pradesh',
                               3:   'Punjab',
                               4:   'Chandigarh',
                               5:   'Uttarakhand',
                               6:   'Haryana',
                               7:   'Nct Of Delhi',
                               8:   'Rajasthan',
                               9:   'Uttar Pradesh',
                               10:  'Bihar',
                               11:  'Sikkim',
                               12:  'Arunachal Pradesh',
                               13:  'Nagaland',
                               14:  'Manipur',
                               15:  'Mizoram',
                               16:  'Tripura',
                               17:  'Meghalaya',
                               18:  'Assam',
                               19:  'West Bengal',
                               20:  'Jharkhand',
                               21:  'Odisha',
                               22:  'Chhattisgarh',
                               23:  'Madhya Pradesh',
                               24:  'Gujarat',
                               25:  'Dadra & Nagar Haveli And Daman & Diu',
                               27:  'Maharashtra',
                               28:  'Andhra Pradesh',
                               29:  'Karnataka',
                               30:  'Goa',
                               31:  'Lakshadweep',
                               32:  'Kerala',
                               33:  'Tamil Nadu',
                               34:  'Puducherry',
                               35:  'Andaman & Nicobar Islands',
                               36:  'Telangana',
                               37:  'Ladakh',}
df19 = df19.replace({"V024": dict})

# %%
dict = {0:  'Cannot read at all',
                               1:  'Able to read only parts of sentence',
                               2:  'Able to read whole sentence',
                               3:  'No card with required language',
                               4:  'Blind/visually impaired',
                               9:  'Missing',
                            ' ':'Not applicable' }
#df_sample = df_sample.replace({df_sample.columns[0]: dict})
df_sample = df_sample.replace({"V155": dict})

# %%
dict = {'0':  'No',
                               '1':  'Vaccination date on card',
                               '2':  'Reported by mother',
                               '3':  'Vaccination marked on card',
                               '8':  'Dont know',
                               '9':  'Missing',
                            ' ':'Not applicable' }
df_sample = df_sample.replace({"H2": dict})

# %%
dict = {'0':  'No education, preschool',
                               '1':  'Primary',
                               '2':  'Secondary',
                               '3':  'Higher',
                               '8':  'Dont know',
                               '9':  'Missing',
                            ' ':'Not applicable' }
df_sample = df_sample.replace({"SV122": dict})

# %%
dict = {0:  'No education',
                               1:  'Primary',
                               2:  'Secondary',
                               3:  'Higher',
                               9:  'Missing',}
df_sample = df_sample.replace({"V106": dict})

# %%
df15 = df15.replace({"V106": dict})
df19 = df19.replace({"V106": dict})

# %% [markdown]
# ### 6. Changing the Index

# %% [markdown]
# # II. Data Transformation

# %% [markdown]
# ## 1. Normalization (Standardization)

# %% [markdown]
# ## 2. Attribute Selection

# %%
# Recursive Feature Elimination
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# create a base classifier used to evaluate a subset of attributes
model = LogisticRegression()
# create the RFE model and select 3 attributes
rfe = RFE(model, n_features_to_select = 3)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False  True  True  True]
# [2 1 1 1]
# C:\Users\shrey\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
rfe
# Out:
# RFE(estimator=LogisticRegression(), n_features_to_select=3)

# %% [markdown]
# # III. Data Reduction

# %% [markdown]
# ## 1. Dimensionality Reduction

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

# %%
encoder = LabelEncoder()
scaler = StandardScaler()

# %%
pca = PCA()

# %% [markdown]
# # Visualization

# %%
type(df_sample['H2'][4])
# Out:
# str

# %%
df_sample.columns.values.tolist()[1:]
# Out:
# ['V155',
#  'V106',
#  'V107',
#  'V133',
#  'H2',
#  'H3',
#  'H4',
#  'H5',
#  'H6',
#  'H7',
#  'H8',
#  'H9']

# %%
df_sample.H2.unique()
# Out:
# array([' ', '2', '1', '3', '0', '8', '9'], dtype=object)

# %%
df.V024.unique()
# Out:
# array([28, 12, 18, 10, 22,  7, 24, 30,  2,  6, 20,  1, 29, 32, 17, 27, 14,
#        23, 15, 13, 21,  3,  8, 11, 33, 16,  5,  9, 19], dtype=int64)

# %%
df['V024']
# Out:
# 0         28
# 1         28
# 2         28
# 3         28
# 4         28
#           ..
# 256777    19
# 256778    19
# 256779    19
# 256780    19
# 256781    19
# Name: V024, Length: 256782, dtype: int64

# %%
df[df['V024']==28]['V023']
# Out:
# 0        28
# 1        28
# 2        28
# 3        28
# 4        28
#          ..
# 13664    28
# 13665    28
# 13666    28
# 13667    28
# 13668    28
# Name: V023, Length: 13669, dtype: int64

# %%
df_sample['V024']
# Out:
# 0         Andhra Pradesh
# 1         Andhra Pradesh
# 2         Andhra Pradesh
# 3         Andhra Pradesh
# 4         Andhra Pradesh
#                ...
# 256777       West Bengal
# 256778       West Bengal
# 256779       West Bengal
# 256780       West Bengal
# 256781       West Bengal
# Name: V024, Length: 256782, dtype: object

# %%
df_sample[df_sample['V024']=='[AP] Andhra Pradesh']['V106']
# Out:
# 0        No education
# 1        No education
# 2        No education
# 3        No education
# 4             Primary
#              ...
# 13664       Secondary
# 13665       Secondary
# 13666    No education
# 13667    No education
# 13668    No education
# Name: V106, Length: 13669, dtype: object

# %%
df_sample[df_sample['V024']=='Andhra Pradesh']['H2']
# Out:
# 0
# 1
# 2
# 3
# 4        2
#         ..
# 13664    1
# 13665    2
# 13666
# 13667
# 13668
# Name: H2, Length: 13669, dtype: object

# %%
df_sample[df_sample['V024']=='[AP] Andhra Pradesh']['V106'].unique()
sum(df_sample[df_sample['V024']=='[AP] Andhra Pradesh']['V106']=="Higher")
# Out:
# 744

# %%
print(df['V106'].unique())
list=[]
for i in df['V106'].unique():
    list.append(sum(df['V106']==i))
print(list)
# Out:
# [0 1 2 3 9]
# [131634, 40801, 72025, 12302, 20]

# %%
df_sample['V106']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 256777    2
# 256778    1
# 256779    1
# 256780    1
# 256781    1
# Name: V106, Length: 256782, dtype: int64

# %%
df_sample['V024'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Delhi', 'Gujarat', 'Goa', 'Himachal Pradesh',
#        'Haryana', 'Jharkhand', 'Jammu and Kashmir', 'Karnataka', 'Kerala',
#        'Meghalaya', 'Maharashtra', 'Manipur', 'Madhya Pradesh', 'Mizoram',
#        'Nagaland', 'Orissa', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttaranchal', 'Uttar Pradesh',
#        'West Bengal'], dtype=object)

# %%
df15
# Out:
#                                 V024  V106
# 0        Andaman and Nicobar Islands     0
# 1        Andaman and Nicobar Islands     0
# 2        Andaman and Nicobar Islands     0
# 3        Andaman and Nicobar Islands     1
# 4        Andaman and Nicobar Islands     1
# ...                              ...   ...
# 1315612                    Telangana     2
# 1315613                    Telangana     0
# 1315614                    Telangana     0
# 1315615                    Telangana     0
# 1315616                    Telangana     0
#
# [1315617 rows x 2 columns]

# %%
df_sample[df_sample['V024']==state]['V106'].unique()
# Out:
# array(['No education', 'Primary', 'Secondary', 'Higher'], dtype=object)

# %%
for state in df_sample['V024'].unique():
    values = ['No education', 'Primary', 'Secondary', 'Higher', 'Missing']
    
    print(df_sample[df_sample['V024']==state]['V106'].unique())
    list1=[]
    for i in values:
        list1.append(sum(df_sample[df_sample['V024']==state]['V106']==i))
    print(list1)
    
    print(df15[df15['V024']==state]['V106'].unique())
    list2=[]
    for i in values:
        list2.append(sum(df15[df15['V024']==state]['V106']==i))
    print(list2)
    
    print(df19[df19['V024']==state]['V106'].unique())
    list3=[]
    for i in values:
        list3.append(sum(df19[df19['V024']==state]['V106']==i))
    print(list3)

    barWidth = 0.25
    br1 = np.arange(len(list1))
    br2 = [x + barWidth for x in br1]
    br3 = [x + barWidth for x in br2]
    
    plt.bar(br1, list1 , color ='maroon',
            width = 0.25, label = '05-06')
    plt.bar(br2, list2 , color ='b',
            width = 0.25, label = '15-16')
    plt.bar(br3, list3 , color ='g',
            width = 0.25, label = '19-21')

    plt.xlabel("Education")
    plt.ylabel("Survey Members")
    plt.title("Education in "+state+" in Years given")
    locs, labels = plt.xticks([r + barWidth for r in range(len(list1))],
        ['No education', 'Primary', 'Secondary', 'Secondary'])
    plt.setp(labels, rotation=90)
    plt.legend()
    plt.show()
# Out:
# ['No education' 'Primary' 'Secondary' 'Higher']
# [6795, 2046, 4084, 744, 0]
# ['No education' 'Primary' 'Higher' 'Secondary']
# [8618, 3001, 5756, 936, 0]
# ['Primary' 'No education' 'Secondary' 'Higher']
# [7433, 3137, 6834, 1134, 0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 37
#      35 plt.ylabel("Survey Members")
#      36 plt.title("Education in "+state+" in Years given")
# ---> 37 locs, labels = plt.xticks([r + barWidth for r in range(len(list1))],
#      38     ['No education', 'Primary', 'Secondary', 'Secondary'])
#      39 plt.setp(labels, rotation=90)
#      40 plt.legend()
#
# File ~\anaconda3\envs\venv\lib\site-packages\matplotlib\pyplot.py:1824, in xticks(ticks, labels, minor, **kwargs)
#    1822         l._internal_update(kwargs)
#    1823 else:
# -> 1824     labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    1826 return locs, labels
#
# File ~\anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\envs\venv\lib\site-packages\matplotlib\axis.py:1968, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1966 if fontdict is not None:
#    1967     kwargs.update(fontdict)
# -> 1968 return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\anaconda3\envs\venv\lib\site-packages\matplotlib\axis.py:1890, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    1886 if isinstance(locator, mticker.FixedLocator):
#    1887     # Passing [] as a list of ticklabels is often used as a way to
#    1888     # remove all tick labels, so only error for > 0 ticklabels
#    1889     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1890         raise ValueError(
#    1891             "The number of FixedLocator locations"
#    1892             f" ({len(locator.locs)}), usually from a call to"
#    1893             " set_ticks, does not match"
#    1894             f" the number of ticklabels ({len(ticklabels)}).")
#    1895     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    1896     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (5), usually from a call to set_ticks, does not match the number of ticklabels (4).

# %%
list=[]
for i in df_sample[df['V023']==28]['V155'].unique():
    list.append(sum(df_sample[df['V023']==28]['V155']==i))
list
# Out:
# [10, 5436, 7297, 882, 20, 24]

# %%
list2=[]
for i in df_sample[df['V023']==28]['H2'].unique():
    list2.append(sum(df_sample[df['V023']==28]['H2']==i))
list2
# Out:
# [11473, 1254, 710, 49, 179, 4]

# %%
#delay = [float(i.split(',')[0].strip()) for i in df_sample.columns.values.tolist()[1:]]

plt.plot(df_sample[df['V023']==28]['V155'].unique(),list, color='b')
plt.plot(df_sample[df['V023']==28]['H2'].unique(),list2, color='r')
plt.xlabel("Values")
plt.ylabel("Survey Members")
locs, labels = plt.xticks()
plt.setp(labels, rotation=90)
plt.legend()
plt.show()
#plt.plot(df_sample['V023'], delay)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for name in df_sample.columns.values.tolist()[1:]:
    plt.plot(df_sample[name],df_sample['V155'],label=name)
    plt.legend(loc='upper left',prop = {'size':7},bbox_to_anchor=(1,1))
    plt.tight_layout(pad=5)
    plt.xlabel ('Literacy')
    plt.ylabel ('Values')
    plt.title ('Tests')
    plt.grid()
    plt.show()

# %%
for name in df_sample.columns.values.tolist()[1:]:
    plt.bar(df_sample[name],df_sample['V155'],label=name)
    plt.legend(loc='upper left',prop = {'size':7},bbox_to_anchor=(1,1))
    plt.tight_layout(pad=5)
    plt.xlabel ('Literacy')
    plt.ylabel ('Values')
    plt.title ('Tests')
    plt.grid()
    plt.show()

# %%
plt.scatter(df['H3'], df['V155'], color='r')
